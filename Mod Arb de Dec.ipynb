# %%
import pandas as pd 
df=pd.read_excel("Date_Fruit_Datasets.xlsx")

# %%
df
# Out:
#        AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0    422163  2378.9080    837.8484    645.6693        0.6373  733.1539
# 1    338136  2085.1440    723.8198    595.2073        0.5690  656.1464
# 2    526843  2647.3940    940.7379    715.3638        0.6494  819.0222
# 3    416063  2351.2100    827.9804    645.2988        0.6266  727.8378
# 4    347562  2160.3540    763.9877    582.8359        0.6465  665.2291
# ..      ...        ...         ...         ...           ...       ...
# 893  255403  1925.3650    691.8453    477.1796        0.7241  570.2536
# 894  365924  2664.8230    855.4633    551.5447        0.7644  682.5752
# 895  254330  1926.7360    747.4943    435.6219        0.8126  569.0545
# 896  238955  1906.2679    716.6485    441.8297        0.7873  551.5859
# 897  343792  2289.2720    823.8438    534.7757        0.7607  661.6113
#
#      SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  KurtosisRR  KurtosisRG  \
# ...

# %%
df=pd.get_dummies(data=df, drop_first=True)

# %%
explicativas=df.drop(columns='AREA')
objetivo=df.AREA
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(max_depth=3)
model.fit(X=explicativas, y=objetivo)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
from sklearn.tree import plot_tree
plot_tree(decision_tree=model, feature_names=explicativas.columns, filled=True, fontsize=5);

# %%
a = explicativas.sample()
a
# Out:
#      PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 567    2547.54    911.9298    620.2306        0.7331  747.2614     0.978
#
#      CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  ...    EntropyRB  \
# 567       448437  0.7127        1.4703     0.8492  ... -49134088192
#
#      ALLdaub4RR  ALLdaub4RG  ALLdaub4RB  Class_DEGLET  Class_DOKOL  \
# 567     60.1073     55.2648     51.4009             0            0
#
#      Class_IRAQI  Class_ROTANA  Class_SAFAVI  Class_SOGAY
# 567            0             1             0            0
#
# [1 rows x 39 columns]

# %%
a
# Out:
#      PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 567    2547.54    911.9298    620.2306        0.7331  747.2614     0.978
#
#      CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  ...    EntropyRB  \
# 567       448437  0.7127        1.4703     0.8492  ... -49134088192
#
#      ALLdaub4RR  ALLdaub4RG  ALLdaub4RB  Class_DEGLET  Class_DOKOL  \
# 567     60.1073     55.2648     51.4009             0            0
#
#      Class_IRAQI  Class_ROTANA  Class_SAFAVI  Class_SOGAY
# 567            0             1             0            0
#
# [1 rows x 39 columns]

# %%
#Interpretar modelo
import seaborn as sns
sns.histplot( x=df.SHAPEFACTOR_4, hue=df.AREA)
# Out:
# <AxesSubplot:xlabel='SHAPEFACTOR_4', ylabel='Count'>
# C:\Users\USUARIO\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
